# %%
# %cd /content/
# %run A5_submission.py
# Out:
# /content
# Percentage of non-zero elements in Luma channel:
# Before compression:  49.508101851851855 %
# After compression:  8.370949074074074 %
